# %% [markdown]
# # Manual experiments with dynamics-related metrics

# %% [markdown]
# > ✅ This notebook can be run locally.

# %% [markdown]
# ## Installing required packages

# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: alabaster==0.7.13 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (0.7.13)
# Requirement already satisfied: Babel==2.13.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (2.13.1)
# Requirement already satisfied: bidict==0.22.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (0.22.1)
# Requirement already satisfied: certifi==2023.7.22 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 4)) (2023.7.22)
# Requirement already satisfied: chardet==5.2.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 5)) (5.2.0)
# Requirement already satisfied: charset-normalizer==3.3.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 6)) (3.3.1)
# Requirement already satisfied: colorama==0.4.6 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: contourpy==1.1.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: cycler==0.12.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: docutils==0.18.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 10)) (0.18.1)
# Requirement already satisfied: exceptiongroup==1.1.3 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 11)) (1.1.3)
# Requirement already satisfied: fonttools==4.43.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 12)) (4.43.1)
# Requirement already satisfied: idna==3.4 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 13)) (3.4)
# Requirement already satisfied: imagesize==1.4.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 14)) (1.4.1)
# Requirement already satisfied: iniconfig==2.0.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: ipykernel==6.28.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 16)) (6.28.0)
# Requirement already satisfied: Jinja2==3.1.2 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 17)) (3.1.2)
# Requirement already satisfied: joblib==1.3.2 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 18)) (1.3.2)
# Requirement already satisfied: jsonpickle==3.0.2 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 19)) (3.0.2)
# Requirement already satisfied: kiwisolver==1.4.5 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 20)) (1.4.5)
# Requirement already satisfied: markdown-it-py==3.0.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 21)) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.3 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 22)) (2.1.3)
# Requirement already satisfied: matplotlib==3.8.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 23)) (3.8.0)
# Requirement already satisfied: mdit-py-plugins==0.4.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 24)) (0.4.0)
# Requirement already satisfied: mdurl==0.1.2 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 25)) (0.1.2)
# Requirement already satisfied: miditok==2.1.8 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 26)) (2.1.8)
# Requirement already satisfied: miditoolkit==1.0.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 27)) (1.0.1)
# Requirement already satisfied: mido==1.3.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 28)) (1.3.0)
# Requirement already satisfied: more-itertools==10.1.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 29)) (10.1.0)
# Requirement already satisfied: music21==9.1.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 30)) (9.1.0)
# Requirement already satisfied: muspy==0.5.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 31)) (0.5.0)
# Requirement already satisfied: myst-parser==2.0.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 32)) (2.0.0)
# Requirement already satisfied: numpy==1.26.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 33)) (1.26.1)
# Requirement already satisfied: packaging==23.2 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 34)) (23.2)
# Requirement already satisfied: Pillow==10.1.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 35)) (10.1.0)
# Requirement already satisfied: pluggy==1.3.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 36)) (1.3.0)
# Requirement already satisfied: pretty-midi==0.2.10 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 37)) (0.2.10)
# Requirement already satisfied: Pygments==2.16.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 38)) (2.16.1)
# Requirement already satisfied: pyparsing==3.1.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 39)) (3.1.1)
# Requirement already satisfied: pypianoroll==1.0.4 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 40)) (1.0.4)
# Requirement already satisfied: pytest==7.4.3 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 41)) (7.4.3)
# Requirement already satisfied: python-dateutil==2.8.2 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 42)) (2.8.2)
# Requirement already satisfied: PyYAML==6.0.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 43)) (6.0.1)
# Requirement already satisfied: requests==2.31.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 44)) (2.31.0)
# Requirement already satisfied: ruff==0.1.2 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 45)) (0.1.2)
# Requirement already satisfied: scipy==1.11.3 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 46)) (1.11.3)
# Requirement already satisfied: six==1.16.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 47)) (1.16.0)
# Requirement already satisfied: snowballstemmer==2.2.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 48)) (2.2.0)
# Requirement already satisfied: Sphinx==7.2.6 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 49)) (7.2.6)
# Requirement already satisfied: sphinx-rtd-theme==1.3.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 50)) (1.3.0)
# Requirement already satisfied: sphinxcontrib-applehelp==1.0.7 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 51)) (1.0.7)
# Requirement already satisfied: sphinxcontrib-devhelp==1.0.5 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 52)) (1.0.5)
# Requirement already satisfied: sphinxcontrib-htmlhelp==2.0.4 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 53)) (2.0.4)
# Requirement already satisfied: sphinxcontrib-jquery==4.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 54)) (4.1)
# Requirement already satisfied: sphinxcontrib-jsmath==1.0.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 55)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp==1.0.6 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 56)) (1.0.6)
# Requirement already satisfied: sphinxcontrib-serializinghtml==1.1.9 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 57)) (1.1.9)
# Requirement already satisfied: tomli==2.0.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 58)) (2.0.1)
# Requirement already satisfied: tqdm==4.66.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 59)) (4.66.1)
# Requirement already satisfied: urllib3==2.0.7 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 60)) (2.0.7)
# Requirement already satisfied: webcolors==1.13 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 61)) (1.13)
# Requirement already satisfied: torch==2.3.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 62)) (2.3.0)
# Requirement already satisfied: unidecode==1.3.8 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from -r ../requirements.txt (line 63)) (1.3.8)
# Requirement already satisfied: comm>=0.1.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (8.22.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (0.1.6)
# Requirement already satisfied: nest-asyncio in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (1.6.0)
# Requirement already satisfied: psutil in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipykernel==6.28.0->-r ../requirements.txt (line 16)) (5.14.2)
# Requirement already satisfied: huggingface-hub>=0.16.4 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from miditok==2.1.8->-r ../requirements.txt (line 26)) (0.23.2)
# Requirement already satisfied: tokenizers>=0.13.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from miditok==2.1.8->-r ../requirements.txt (line 26)) (0.19.1)
# Requirement already satisfied: filelock in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from torch==2.3.0->-r ../requirements.txt (line 62)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from torch==2.3.0->-r ../requirements.txt (line 62)) (4.10.0)
# Requirement already satisfied: sympy in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from torch==2.3.0->-r ../requirements.txt (line 62)) (1.12)
# Requirement already satisfied: networkx in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from torch==2.3.0->-r ../requirements.txt (line 62)) (3.3)
# Requirement already satisfied: fsspec in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from torch==2.3.0->-r ../requirements.txt (line 62)) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from torch==2.3.0->-r ../requirements.txt (line 62)) (2021.4.0)
# Requirement already satisfied: decorator in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (3.0.43)
# Requirement already satisfied: stack-data in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (4.2.0)
# Requirement already satisfied: pywin32>=300 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (306)
# Requirement already satisfied: intel-openmp==2021.* in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.0->-r ../requirements.txt (line 62)) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.0->-r ../requirements.txt (line 62)) (2021.12.0)
# Requirement already satisfied: mpmath>=0.19 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from sympy->torch==2.3.0->-r ../requirements.txt (line 62)) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: wcwidth in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: pure-eval in d:\proste\studia\archiwa\mag inteligentne systemy\vs code\wimu\wimu-midi-metrics\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.28.0->-r ../requirements.txt (line 16)) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importing tested methods

# %%
import os  # noqa: E402
import sys  # noqa: E402

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from wimu10 import (  # noqa: E402
    compute_dynamics_histogram,
    compute_dynamics_levels_histogram,
    compute_dynamics_variability,
    compute_dynamics_levels_variability,
    compute_dynamics_transition_matrix,
    compute_dynamics_levels_transition_matrix,
)

# %% [markdown]
# ## Setting up a dataset

# %%
dataset = 'musicnet'  # 'musicnet', 'maestro', 'nesmdb', 'emopia', 'lakh'

# %%
from setup_dataset import download_muspy_midi, change_data_path  # noqa: E402

change_data_path('../data/raw/')
downloaded_dataset = download_muspy_midi(dataset)  # Performs required extraction and conversion

print(f'The chosen dataset ({type(downloaded_dataset).__name__}) has {len(downloaded_dataset)} elements.')
# Out:
# Skip downloading as the `.muspy.success` file is found.
# Skip extracting as the `.muspy.success` file is found.
# Skip conversion as the `.muspy.success` file is found.
# The chosen dataset (MusicNetDataset) has 323 elements.

# %% [markdown]
# ## Processing a file (of choice)

# %%
# Choose a file from the dataset by putting its index here
# The index should be the zero-based index of a file converted by MusPy when setting up the dataset
file_index: int = 199

# Alternatively you can put a full (relative or absolute) path to a MIDI file to be processed here
# Leave empty to use the file_index field
full_file_path: str = ''

# %%
from os import listdir  # noqa: E402
from pathlib import Path  # noqa: E402

import matplotlib.pyplot as plt  # noqa: E402
import muspy as mp  # noqa: E402
import numpy as np  # noqa: E402

from setup_dataset import DATA_RAW_PATH  # noqa: E402

full_path_used = full_file_path != ''

if full_path_used:
    path = Path(full_file_path)
else:
    extension = '.json'
    first_dataset_entry = sorted(
        filter(
            lambda filename: filename.endswith(extension),
            listdir(Path(f'{DATA_RAW_PATH}{dataset}/_converted/'))
        )
    )[0]
    first_dataset_entry = first_dataset_entry[:-len(extension)]
    padding_len = len(first_dataset_entry)
    path = Path(f'{DATA_RAW_PATH}{dataset}/_converted/{str(file_index).zfill(padding_len)}{extension}')

if not path.exists() or not path.is_file():
    raise Exception(f'There is no file at path: {path}')

if full_path_used:
    music = mp.read_midi(path)
else:
    music = mp.load_json(path)

print(f'Loaded file: {path} (source filename: {music.metadata.source_filename}, title: {music.metadata.title})')

resolution = int(music.resolution / 4)  # MIDI resolution is in quarternotes, divided by 4 gives 1/16 note accuracy
track_end = music.get_end_time()
total_scores = []
dynamics_levels = ['ppp', 'pp', 'p', 'mp', 'mf', 'f', 'ff', 'fff']  # Default dynamics levels used

for track_idx, track in enumerate(music.tracks):
    print()
    print(f'=== PROCESSING TRACK #{track_idx} ===')
    if len(track.notes) == 0:
        total_scores.append(None)
        print(f'  Skipping track {track_idx} (it has 0 notes).')
        continue

    # Calculate all metrics
    bins = compute_dynamics_histogram(music, track_idx, resolution=resolution, track_end=track_end)
    level_bins = compute_dynamics_levels_histogram(music, track_idx, resolution=resolution, track_end=track_end)
    variability = compute_dynamics_variability(music, track_idx, resolution=resolution, track_end=track_end)
    level_variability = compute_dynamics_levels_variability(music, track_idx, resolution=resolution, track_end=track_end)
    transition_matrix = compute_dynamics_transition_matrix(music, track_idx, resolution=resolution, track_end=track_end)
    level_transition_matrix = compute_dynamics_levels_transition_matrix(
        music, track_idx, resolution=resolution, track_end=track_end
    )

    # Add metrics to a list (for saving it to a file later)
    total_scores.append(
        {
            'histogram': bins,
            'level_histogram': level_bins,
            'variability': variability,
            'level_variability': level_variability,
            'transition_matrix': transition_matrix.tolist(),
            'level_transition_matrix': level_transition_matrix.tolist(),
        }
    )

    # Plotting histograms
    _, (a1, a2) = plt.subplots(1, 2, figsize=(12, 4))
    a1.bar(range(len(bins)), bins)
    a1.set_title('Velocity values histogram')
    a2.bar(range(len(level_bins)), level_bins)
    a2.set_title('Dynamics levels histogram')
    a2.set_xticks(range(len(dynamics_levels)), dynamics_levels)
    plt.show()

    # Plotting transition matrices
    fig, (a1, a2) = plt.subplots(1, 2, figsize=(12, 6))
    plt.colorbar(a1.imshow(transition_matrix), ax=a1, fraction=0.03)
    a1.set_title('Velocity values transition matrix')
    plt.colorbar(a2.imshow(level_transition_matrix), ax=a2, fraction=0.03)
    a2.set_title('Dynamics levels transition matrix')
    a2.set_xticks(range(len(dynamics_levels)), dynamics_levels)
    a2.set_yticks(range(len(dynamics_levels)), dynamics_levels)
    plt.show()

    # Plotting transition matrices with zeroed diagonal
    np.fill_diagonal(transition_matrix, 0)
    np.fill_diagonal(level_transition_matrix, 0)
    fig, (a1, a2) = plt.subplots(1, 2, figsize=(12, 6))
    plt.colorbar(a1.imshow(transition_matrix), ax=a1, fraction=0.03)
    a1.set_title('Velocity values transition matrix (with zeroed diagonal)')
    plt.colorbar(a2.imshow(level_transition_matrix), ax=a2, fraction=0.03)
    a2.set_title('Dynamics levels transition matrix (with zeroed diagonal)')
    a2.set_xticks(range(len(dynamics_levels)), dynamics_levels)
    a2.set_yticks(range(len(dynamics_levels)), dynamics_levels)
    plt.show()

    # Describing variability
    print(f'Velocity values variability: {variability.ratio[0] * 100:.2f}% ({variability.changes_count[0]} / {variability.total_count})')
    print('Dynamics levels variability:')
    print(f'- lesser changes (1..2 levels): {level_variability.ratio[0] * 100:.2f}% ({level_variability.changes_count[0]} / {level_variability.total_count})')
    print(f'- greater changes (3+ levels): {level_variability.ratio[1] * 100:.2f}% ({level_variability.changes_count[1]} / {level_variability.total_count})')
# Out:
# Loaded file: ..\data\raw\musicnet\_converted\199.json (source filename: 2588_ps12_01.mid, title: L.v.Beethoven 1mov - Piano Sonata No.12 in Ab Major Op.26)
#
# === PROCESSING TRACK #0 ===
# Velocity values variability: 9.49% (120 / 1265)
# Dynamics levels variability:
# - lesser changes (1..2 levels): 2.61% (33 / 1265)
# - greater changes (3+ levels): 0.00% (0 / 1265)
#
# === PROCESSING TRACK #1 ===
# Velocity values variability: 7.56% (91 / 1204)
# Dynamics levels variability:
# - lesser changes (1..2 levels): 1.41% (17 / 1204)
# - greater changes (3+ levels): 0.00% (0 / 1204)

# %% [markdown]
# ## Saving results

# %%
from datetime import datetime  # noqa: E402
import json  # noqa: E402
from os import makedirs  # noqa: E402

results_dir = '../results/dynamics/'
makedirs(results_dir, exist_ok=True)
current_datetime = datetime.now().strftime('%Y%m%d-%H%M%S')
results_filename = f'{results_dir}{path.stem}_{current_datetime}.json'
with open(results_filename, 'w') as f:
    json.dump(total_scores, f, indent=4)
    print(f'Results saved to {results_filename}')
# Out:
# Results saved to ../results/dynamics/329_20240116-230612.json
